# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
city_data = []

# %%
len(city_data)
# Out:
# 0

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descr = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_descr,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dakar
# Processing Record 2 of Set 1 | husavik
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | lavrentiya
# Processing Record 5 of Set 1 | thinadhoo
# Processing Record 6 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | geraldton
# Processing Record 9 of Set 1 | kuntaur
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | faya
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | venice
# Processing Record 14 of Set 1 | alofi
# Processing Record 15 of Set 1 | kattivakkam
# Processing Record 16 of Set 1 | kavieng
# Processing Record 17 of Set 1 | faanui
# Processing Record 18 of Set 1 | port blair
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | beringovskiy
# Processing Record 21 of Set 1 | leticia
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | buala
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | itarema
# Processing Record 28 of Set 1 | sao jose do belmonte
# Processing Record 29 of Set 1 | deputatskiy
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | nome
# Processing Record 32 of Set 1 | caborca
# Processing Record 33 of Set 1 | sovetskaya gavan
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | kresttsy
# Processing Record 40 of Set 1 | vardo
# Processing Record 41 of Set 1 | chara
# Processing Record 42 of Set 1 | poronaysk
# Processing Record 43 of Set 1 | hinton
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | port lincoln
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | provideniya
# Processing Record 49 of Set 1 | san julian
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | pernik
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | xining
# Processing Record 8 of Set 2 | ilulissat
# Processing Record 9 of Set 2 | awbari
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | erseke
# Processing Record 12 of Set 2 | bandarbeyla
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | esperance
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | ngong
# Processing Record 18 of Set 2 | neuquen
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | bereda
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | floro
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | sisimiut
# Processing Record 27 of Set 2 | la tuque
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | zheshart
# Processing Record 30 of Set 2 | finschhafen
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | llangefni
# Processing Record 33 of Set 2 | atambua
# Processing Record 34 of Set 2 | kavaratti
# Processing Record 35 of Set 2 | nikki
# Processing Record 36 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | nongan
# Processing Record 39 of Set 2 | killarney
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | whitehorse
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 2 | flagstaff
# Processing Record 48 of Set 2 | san quintin
# Processing Record 49 of Set 2 | sorkjosen
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | constantine
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | monrovia
# Processing Record 5 of Set 3 | camopi
# Processing Record 6 of Set 3 | santa isabel do rio negro
# Processing Record 7 of Set 3 | kalispell
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | laguna
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | kitimat
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 3 | uige
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | zemio
# Processing Record 17 of Set 3 | solnechnyy
# Processing Record 18 of Set 3 | barrow
# Processing Record 19 of Set 3 | steamboat springs
# Processing Record 20 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 3 | maua
# Processing Record 22 of Set 3 | tokoroa
# Processing Record 23 of Set 3 | totness
# Processing Record 24 of Set 3 | madridejos
# Processing Record 25 of Set 3 | soderhamn
# Processing Record 26 of Set 3 | port macquarie
# Processing Record 27 of Set 3 | we
# City not found. Skipping...
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | bathsheba
# Processing Record 33 of Set 3 | qandala
# Processing Record 34 of Set 3 | coahuayana
# Processing Record 35 of Set 3 | palmer
# Processing Record 36 of Set 3 | bilibino
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | kokstad
# Processing Record 41 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | hualmay
# Processing Record 43 of Set 3 | flinders
# Processing Record 44 of Set 3 | asau
# Processing Record 45 of Set 3 | ulaangom
# Processing Record 46 of Set 3 | iquitos
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | villamontes
# Processing Record 1 of Set 4 | kenai
# Processing Record 2 of Set 4 | folldal
# Processing Record 3 of Set 4 | yellowknife
# Processing Record 4 of Set 4 | koson
# Processing Record 5 of Set 4 | amancio
# City not found. Skipping...
# Processing Record 6 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | saskylakh
# Processing Record 9 of Set 4 | vila velha
# Processing Record 10 of Set 4 | aswan
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | serra talhada
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | cap malheureux
# Processing Record 16 of Set 4 | iqaluit
# Processing Record 17 of Set 4 | lungi
# Processing Record 18 of Set 4 | susanville
# Processing Record 19 of Set 4 | miles city
# Processing Record 20 of Set 4 | blagoyevo
# Processing Record 21 of Set 4 | beyneu
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 4 | lieksa
# Processing Record 26 of Set 4 | karwar
# Processing Record 27 of Set 4 | chokurdakh
# Processing Record 28 of Set 4 | sobolevo
# Processing Record 29 of Set 4 | sao joao da barra
# Processing Record 30 of Set 4 | haines junction
# Processing Record 31 of Set 4 | katherine
# Processing Record 32 of Set 4 | inta
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | hoquiam
# Processing Record 35 of Set 4 | puerto ayora
# Processing Record 36 of Set 4 | coihaique
# Processing Record 37 of Set 4 | sembakung
# Processing Record 38 of Set 4 | boca do acre
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | burns lake
# Processing Record 41 of Set 4 | tallahassee
# Processing Record 42 of Set 4 | ereymentau
# Processing Record 43 of Set 4 | porto novo
# Processing Record 44 of Set 4 | poitiers
# Processing Record 45 of Set 4 | tshikapa
# Processing Record 46 of Set 4 | leningradskiy
# Processing Record 47 of Set 4 | ciudad real
# Processing Record 48 of Set 4 | bentiu
# Processing Record 49 of Set 4 | sortavala
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | lasa
# Processing Record 2 of Set 5 | pangkalanbuun
# Processing Record 3 of Set 5 | paamiut
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | portland
# Processing Record 6 of Set 5 | quelimane
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | castlebar
# Processing Record 9 of Set 5 | inirida
# Processing Record 10 of Set 5 | noumea
# Processing Record 11 of Set 5 | brae
# Processing Record 12 of Set 5 | sayla
# Processing Record 13 of Set 5 | sibu
# Processing Record 14 of Set 5 | oistins
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | miyako
# Processing Record 17 of Set 5 | banjar
# Processing Record 18 of Set 5 | beni
# Processing Record 19 of Set 5 | hami
# Processing Record 20 of Set 5 | ambilobe
# Processing Record 21 of Set 5 | baijiantan
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | veraval
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | nemuro
# Processing Record 26 of Set 5 | sesheke
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | taltal
# Processing Record 29 of Set 5 | port shepstone
# Processing Record 30 of Set 5 | hearst
# Processing Record 31 of Set 5 | la mana
# Processing Record 32 of Set 5 | ozinki
# Processing Record 33 of Set 5 | corralillo
# Processing Record 34 of Set 5 | samarai
# Processing Record 35 of Set 5 | nador
# Processing Record 36 of Set 5 | bilma
# Processing Record 37 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | nalut
# Processing Record 40 of Set 5 | luau
# Processing Record 41 of Set 5 | touros
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | quesnel
# Processing Record 44 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 47 of Set 5 | hauterive
# Processing Record 48 of Set 5 | statesboro
# Processing Record 49 of Set 5 | kundiawa
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | sikeston
# Processing Record 2 of Set 6 | karasjok
# Processing Record 3 of Set 6 | praia
# Processing Record 4 of Set 6 | ostrovnoy
# Processing Record 5 of Set 6 | farmington
# Processing Record 6 of Set 6 | shakawe
# Processing Record 7 of Set 6 | mar del plata
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | bambanglipuro
# Processing Record 10 of Set 6 | gorontalo
# Processing Record 11 of Set 6 | quatre cocos
# Processing Record 12 of Set 6 | general pico
# Processing Record 13 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 6 | turukhansk
# Processing Record 15 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 6 | creel
# Processing Record 17 of Set 6 | tocopilla
# Processing Record 18 of Set 6 | aklavik
# Processing Record 19 of Set 6 | namatanai
# Processing Record 20 of Set 6 | jieshi
# Processing Record 21 of Set 6 | mount gambier
# Processing Record 22 of Set 6 | atar
# Processing Record 23 of Set 6 | diban
# Processing Record 24 of Set 6 | harindanga
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | zakamensk
# Processing Record 27 of Set 6 | neftcala
# Processing Record 28 of Set 6 | ulundi
# Processing Record 29 of Set 6 | lethem
# Processing Record 30 of Set 6 | svetlaya
# Processing Record 31 of Set 6 | shimoda
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | banda aceh
# Processing Record 34 of Set 6 | calvinia
# Processing Record 35 of Set 6 | yerbogachen
# Processing Record 36 of Set 6 | kirovskiy
# Processing Record 37 of Set 6 | sumbe
# Processing Record 38 of Set 6 | villa carlos paz
# Processing Record 39 of Set 6 | lalibela
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | port hedland
# Processing Record 42 of Set 6 | nuuk
# Processing Record 43 of Set 6 | rochefort
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | khatassy
# Processing Record 46 of Set 6 | olafsvik
# Processing Record 47 of Set 6 | flin flon
# Processing Record 48 of Set 6 | khatanga
# Processing Record 49 of Set 6 | maldonado
# Processing Record 50 of Set 6 | lundazi
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | oussouye
# Processing Record 3 of Set 7 | puerto del rosario
# Processing Record 4 of Set 7 | guerrero negro
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | hobyo
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | nelidovo
# Processing Record 9 of Set 7 | tabuk
# Processing Record 10 of Set 7 | vila
# Processing Record 11 of Set 7 | valdivia
# Processing Record 12 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 13 of Set 7 | marsh harbour
# Processing Record 14 of Set 7 | queimadas
# Processing Record 15 of Set 7 | labuhan
# Processing Record 16 of Set 7 | necochea
# Processing Record 17 of Set 7 | hofn
# Processing Record 18 of Set 7 | roebourne
# Processing Record 19 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 7 | nouakchott
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | lebu
# Processing Record 23 of Set 7 | boyabat
# Processing Record 24 of Set 7 | bintulu
# Processing Record 25 of Set 7 | panzhihua
# Processing Record 26 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 7 | tacoronte
# Processing Record 28 of Set 7 | dourados
# Processing Record 29 of Set 7 | onda
# Processing Record 30 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 7 | kangaatsiaq
# Processing Record 32 of Set 7 | artigas
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | sao filipe
# Processing Record 35 of Set 7 | puerto escondido
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | adeje
# Processing Record 38 of Set 7 | botwood
# Processing Record 39 of Set 7 | ukiah
# Processing Record 40 of Set 7 | pochutla
# Processing Record 41 of Set 7 | rio cuarto
# Processing Record 42 of Set 7 | bengkulu
# Processing Record 43 of Set 7 | broken arrow
# Processing Record 44 of Set 7 | matadi
# Processing Record 45 of Set 7 | kahului
# Processing Record 46 of Set 7 | nikolskoye
# Processing Record 47 of Set 7 | rwamagana
# Processing Record 48 of Set 7 | rawah
# Processing Record 49 of Set 7 | sarangani
# Processing Record 50 of Set 7 | tuatapere
# Processing Record 1 of Set 8 | ocos
# Processing Record 2 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 3 of Set 8 | paramonga
# Processing Record 4 of Set 8 | broome
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | robertson
# Processing Record 7 of Set 8 | pervomaysk
# Processing Record 8 of Set 8 | yatou
# Processing Record 9 of Set 8 | egvekinot
# Processing Record 10 of Set 8 | rawson
# Processing Record 11 of Set 8 | wakkanai
# Processing Record 12 of Set 8 | gonbad-e qabus
# Processing Record 13 of Set 8 | alvorada
# Processing Record 14 of Set 8 | birao
# Processing Record 15 of Set 8 | manaure
# Processing Record 16 of Set 8 | storslett
# Processing Record 17 of Set 8 | avallon
# Processing Record 18 of Set 8 | ponta delgada
# Processing Record 19 of Set 8 | souillac
# Processing Record 20 of Set 8 | bud
# Processing Record 21 of Set 8 | kidal
# Processing Record 22 of Set 8 | ancud
# Processing Record 23 of Set 8 | rzhyshchiv
# Processing Record 24 of Set 8 | lahaina
# Processing Record 25 of Set 8 | do gonbadan
# Processing Record 26 of Set 8 | burica
# City not found. Skipping...
# Processing Record 27 of Set 8 | midyat
# Processing Record 28 of Set 8 | bundoran
# Processing Record 29 of Set 8 | hede
# Processing Record 30 of Set 8 | kjollefjord
# Processing Record 31 of Set 8 | adrar
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | mozarlandia
# Processing Record 34 of Set 8 | brokopondo
# Processing Record 35 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 8 | ranong
# Processing Record 37 of Set 8 | tilichiki
# Processing Record 38 of Set 8 | gopalpur
# Processing Record 39 of Set 8 | saint-joseph
# Processing Record 40 of Set 8 | luganville
# Processing Record 41 of Set 8 | narsaq
# Processing Record 42 of Set 8 | ayna
# Processing Record 43 of Set 8 | bouna
# Processing Record 44 of Set 8 | auki
# Processing Record 45 of Set 8 | chapais
# Processing Record 46 of Set 8 | erenhot
# Processing Record 47 of Set 8 | borba
# Processing Record 48 of Set 8 | ye
# City not found. Skipping...
# Processing Record 49 of Set 8 | rosarito
# Processing Record 50 of Set 8 | tandil
# Processing Record 1 of Set 9 | gorlitz
# Processing Record 2 of Set 9 | pachino
# Processing Record 3 of Set 9 | prince rupert
# Processing Record 4 of Set 9 | kamenka
# Processing Record 5 of Set 9 | jumla
# Processing Record 6 of Set 9 | black river
# Processing Record 7 of Set 9 | bonthe
# Processing Record 8 of Set 9 | dunedin
# Processing Record 9 of Set 9 | cuamba
# Processing Record 10 of Set 9 | sorong
# Processing Record 11 of Set 9 | ribeira grande
# Processing Record 12 of Set 9 | tezu
# Processing Record 13 of Set 9 | dugna
# City not found. Skipping...
# Processing Record 14 of Set 9 | soria
# Processing Record 15 of Set 9 | zilair
# Processing Record 16 of Set 9 | dunmore town
# Processing Record 17 of Set 9 | cascais
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | kathmandu
# Processing Record 20 of Set 9 | qaqortoq
# Processing Record 21 of Set 9 | chandvad
# Processing Record 22 of Set 9 | margate
# Processing Record 23 of Set 9 | andilamena
# Processing Record 24 of Set 9 | zykovo
# Processing Record 25 of Set 9 | daru
# Processing Record 26 of Set 9 | xixiang
# Processing Record 27 of Set 9 | stromness
# Processing Record 28 of Set 9 | klaksvik
# Processing Record 29 of Set 9 | sapele
# Processing Record 30 of Set 9 | bose
# Processing Record 31 of Set 9 | yambio
# Processing Record 32 of Set 9 | vanimo
# Processing Record 33 of Set 9 | pringsewu
# Processing Record 34 of Set 9 | luquillo
# Processing Record 35 of Set 9 | roald
# Processing Record 36 of Set 9 | sheridan
# Processing Record 37 of Set 9 | macusani
# Processing Record 38 of Set 9 | luderitz
# Processing Record 39 of Set 9 | nueva gerona
# Processing Record 40 of Set 9 | kemijarvi
# Processing Record 41 of Set 9 | vostok
# Processing Record 42 of Set 9 | tuensang
# Processing Record 43 of Set 9 | minab
# Processing Record 44 of Set 9 | lamesa
# Processing Record 45 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 9 | serebryansk
# Processing Record 47 of Set 9 | ofunato
# Processing Record 48 of Set 9 | kedougou
# Processing Record 49 of Set 9 | kindberg
# Processing Record 50 of Set 9 | gao
# Processing Record 1 of Set 10 | chik
# Processing Record 2 of Set 10 | nanakuli
# Processing Record 3 of Set 10 | xiamen
# Processing Record 4 of Set 10 | orlik
# Processing Record 5 of Set 10 | olinda
# Processing Record 6 of Set 10 | victoria
# Processing Record 7 of Set 10 | boralday
# Processing Record 8 of Set 10 | kungurtug
# Processing Record 9 of Set 10 | rebrikha
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | khromtau
# Processing Record 12 of Set 10 | saint-georges
# Processing Record 13 of Set 10 | richards bay
# Processing Record 14 of Set 10 | phek
# Processing Record 15 of Set 10 | altay
# Processing Record 16 of Set 10 | garden city
# Processing Record 17 of Set 10 | marsaxlokk
# Processing Record 18 of Set 10 | yeppoon
# Processing Record 19 of Set 10 | ilinge
# Processing Record 20 of Set 10 | westport
# Processing Record 21 of Set 10 | kewanee
# Processing Record 22 of Set 10 | dingle
# Processing Record 23 of Set 10 | beira
# Processing Record 24 of Set 10 | la rioja
# Processing Record 25 of Set 10 | matagami
# Processing Record 26 of Set 10 | roros
# Processing Record 27 of Set 10 | lompoc
# Processing Record 28 of Set 10 | tessalit
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | starosubkhangulovo
# Processing Record 31 of Set 10 | grenaa
# Processing Record 32 of Set 10 | salalah
# Processing Record 33 of Set 10 | caluquembe
# Processing Record 34 of Set 10 | saint-ambroise
# Processing Record 35 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 10 | vestmannaeyjar
# Processing Record 37 of Set 10 | moerai
# Processing Record 38 of Set 10 | sakyla
# Processing Record 39 of Set 10 | kodinsk
# Processing Record 40 of Set 10 | windsor
# Processing Record 41 of Set 10 | bairiki
# Processing Record 42 of Set 10 | uruacu
# Processing Record 43 of Set 10 | mogadishu
# Processing Record 44 of Set 10 | esmeraldas
# Processing Record 45 of Set 10 | valverde del camino
# Processing Record 46 of Set 10 | gurupi
# Processing Record 47 of Set 10 | sabha
# Processing Record 48 of Set 10 | de haan
# Processing Record 49 of Set 10 | tromso
# Processing Record 50 of Set 10 | acajutla
# Processing Record 1 of Set 11 | alta floresta
# Processing Record 2 of Set 11 | amalapuram
# Processing Record 3 of Set 11 | kedrovyy
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | nadbai
# Processing Record 6 of Set 11 | riviere-au-renard
# Processing Record 7 of Set 11 | heishan
# Processing Record 8 of Set 11 | alekseyevsk
# Processing Record 9 of Set 11 | inongo
# Processing Record 10 of Set 11 | tanout
# Processing Record 11 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 11 | kojnare
# Processing Record 14 of Set 11 | berlevag
# Processing Record 15 of Set 11 | mazamari
# Processing Record 16 of Set 11 | rajura
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | tlacotepec
# Processing Record 19 of Set 11 | kudahuvadhoo
# Processing Record 20 of Set 11 | mandalgovi
# Processing Record 21 of Set 11 | ribas do rio pardo
# Processing Record 22 of Set 11 | chifeng
# Processing Record 23 of Set 11 | pascagoula
# Processing Record 24 of Set 11 | edd
# Processing Record 25 of Set 11 | zhigansk
# Processing Record 26 of Set 11 | nelson bay
# Processing Record 27 of Set 11 | carutapera
# Processing Record 28 of Set 11 | acarau
# Processing Record 29 of Set 11 | honiara
# Processing Record 30 of Set 11 | lima
# Processing Record 31 of Set 11 | ciudad bolivar
# Processing Record 32 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 11 | kankaanpaa
# Processing Record 34 of Set 11 | kibala
# Processing Record 35 of Set 11 | zeya
# Processing Record 36 of Set 11 | marzuq
# Processing Record 37 of Set 11 | marawi
# Processing Record 38 of Set 11 | gamba
# Processing Record 39 of Set 11 | dudinka
# Processing Record 40 of Set 11 | damghan
# Processing Record 41 of Set 11 | te anau
# Processing Record 42 of Set 11 | mineral wells
# Processing Record 43 of Set 11 | emba
# Processing Record 44 of Set 11 | katsuura
# Processing Record 45 of Set 11 | carcassonne
# Processing Record 46 of Set 11 | guider
# Processing Record 47 of Set 11 | banfora
# Processing Record 48 of Set 11 | redlands
# Processing Record 49 of Set 11 | durant
# Processing Record 50 of Set 11 | kyshtovka
# Processing Record 1 of Set 12 | kaeo
# Processing Record 2 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 12 | alyangula
# Processing Record 4 of Set 12 | safaga
# Processing Record 5 of Set 12 | tura
# Processing Record 6 of Set 12 | sur
# Processing Record 7 of Set 12 | haveli
# Processing Record 8 of Set 12 | yar-sale
# Processing Record 9 of Set 12 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 10 of Set 12 | pokhara
# Processing Record 11 of Set 12 | rapar
# Processing Record 12 of Set 12 | igarka
# Processing Record 13 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 14 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 15 of Set 12 | voyvozh
# Processing Record 16 of Set 12 | pozoblanco
# Processing Record 17 of Set 12 | bolgatanga
# Processing Record 18 of Set 12 | korla
# Processing Record 19 of Set 12 | boende
# Processing Record 20 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 12 | sept-iles
# Processing Record 22 of Set 12 | phan thiet
# Processing Record 23 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 12 | vinkovci
# Processing Record 25 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 12 | ntchisi
# Processing Record 27 of Set 12 | edson
# Processing Record 28 of Set 12 | namibe
# Processing Record 29 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 12 | nioro
# Processing Record 32 of Set 12 | anadyr
# Processing Record 33 of Set 12 | manado
# Processing Record 34 of Set 12 | ixtapa
# Processing Record 35 of Set 12 | hirado
# Processing Record 36 of Set 12 | tahoua
# Processing Record 37 of Set 12 | luanda
# Processing Record 38 of Set 12 | komsomolets
# Processing Record 39 of Set 12 | emerald
# Processing Record 40 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 12 | port hardy
# Processing Record 42 of Set 12 | karakol
# Processing Record 43 of Set 12 | burnie
# Processing Record 44 of Set 12 | san juan del sur
# Processing Record 45 of Set 12 | arroyo
# Processing Record 46 of Set 12 | sabang
# Processing Record 47 of Set 12 | cabo san lucas
# Processing Record 48 of Set 12 | port moresby
# Processing Record 49 of Set 12 | cayenne
# Processing Record 50 of Set 12 | ibra
# Processing Record 1 of Set 13 | sinegorye
# Processing Record 2 of Set 13 | kloulklubed
# Processing Record 3 of Set 13 | ahipara
# Processing Record 4 of Set 13 | tyukhtet
# Processing Record 5 of Set 13 | opole
# Processing Record 6 of Set 13 | hondo
# Processing Record 7 of Set 13 | the valley
# Processing Record 8 of Set 13 | acapulco
# Processing Record 9 of Set 13 | pitimbu
# Processing Record 10 of Set 13 | bethanien
# Processing Record 11 of Set 13 | constitucion
# Processing Record 12 of Set 13 | cilegon
# Processing Record 13 of Set 13 | sayabec
# City not found. Skipping...
# Processing Record 14 of Set 13 | brasileia
# Processing Record 15 of Set 13 | port-cartier
# Processing Record 16 of Set 13 | havoysund
# Processing Record 17 of Set 13 | kovdor
# Processing Record 18 of Set 13 | high level
# Processing Record 19 of Set 13 | liverpool
# Processing Record 20 of Set 13 | almaznyy
# Processing Record 21 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 13 | lake havasu city
# Processing Record 23 of Set 13 | puerto madryn
# Processing Record 24 of Set 13 | concepcion
# Processing Record 25 of Set 13 | pinsk
# Processing Record 26 of Set 13 | znamenka
# Processing Record 27 of Set 13 | abeche
# Processing Record 28 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 13 | contamana
# Processing Record 30 of Set 13 | noyabrsk
# Processing Record 31 of Set 13 | san jose
# Processing Record 32 of Set 13 | garmsar
# Processing Record 33 of Set 13 | jobat
# Processing Record 34 of Set 13 | port augusta
# Processing Record 35 of Set 13 | sekoma
# Processing Record 36 of Set 13 | guadalupe y calvo
# Processing Record 37 of Set 13 | goderich
# Processing Record 38 of Set 13 | talcahuano
# Processing Record 39 of Set 13 | kirakira
# Processing Record 40 of Set 13 | weinan
# Processing Record 41 of Set 13 | mindelo
# Processing Record 42 of Set 13 | takaka
# Processing Record 43 of Set 13 | tutoia
# Processing Record 44 of Set 13 | cheney
# Processing Record 45 of Set 13 | smithers
# Processing Record 46 of Set 13 | calama
# Processing Record 47 of Set 13 | jalu
# Processing Record 48 of Set 13 | san vicente
# Processing Record 49 of Set 13 | taganak
# Processing Record 50 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 14 | biak
# Processing Record 2 of Set 14 | canitas
# City not found. Skipping...
# Processing Record 3 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 4 of Set 14 | lugovoy
# Processing Record 5 of Set 14 | rota
# Processing Record 6 of Set 14 | viedma
# Processing Record 7 of Set 14 | hurghada
# Processing Record 8 of Set 14 | asosa
# Processing Record 9 of Set 14 | grand-santi
# Processing Record 10 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 14 | am timan
# Processing Record 12 of Set 14 | ariquemes
# Processing Record 13 of Set 14 | malakal
# Processing Record 14 of Set 14 | stornoway
# Processing Record 15 of Set 14 | otjiwarongo
# Processing Record 16 of Set 14 | havre-saint-pierre
# Processing Record 17 of Set 14 | kastamonu
# Processing Record 18 of Set 14 | rach gia
# Processing Record 19 of Set 14 | sakakah
# Processing Record 20 of Set 14 | tual
# Processing Record 21 of Set 14 | savinskiy
# Processing Record 22 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 14 | jinka
# Processing Record 24 of Set 14 | jiangyou
# Processing Record 25 of Set 14 | duarte
# Processing Record 26 of Set 14 | panguna
# Processing Record 27 of Set 14 | zaysan
# Processing Record 28 of Set 14 | dharchula
# Processing Record 29 of Set 14 | kabanjahe
# Processing Record 30 of Set 14 | ouesso
# Processing Record 31 of Set 14 | dicabisagan
# Processing Record 32 of Set 14 | mwene-ditu
# Processing Record 33 of Set 14 | kokopo
# Processing Record 34 of Set 14 | chake chake
# Processing Record 35 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 14 | panjwin
# City not found. Skipping...
# Processing Record 37 of Set 14 | williams lake
# Processing Record 38 of Set 14 | shubarshi
# Processing Record 39 of Set 14 | kang
# Processing Record 40 of Set 14 | urumqi
# Processing Record 41 of Set 14 | bonavista
# Processing Record 42 of Set 14 | okha
# Processing Record 43 of Set 14 | xunchang
# Processing Record 44 of Set 14 | mae sai
# Processing Record 45 of Set 14 | abha
# Processing Record 46 of Set 14 | skegness
# Processing Record 47 of Set 14 | tazovskiy
# Processing Record 48 of Set 14 | ellisras
# Processing Record 49 of Set 14 | shima
# Processing Record 50 of Set 14 | mount isa
# Processing Record 1 of Set 15 | brattleboro
# Processing Record 2 of Set 15 | usinsk
# Processing Record 3 of Set 15 | carolina
# Processing Record 4 of Set 15 | spokoynaya
# Processing Record 5 of Set 15 | kurdzhinovo
# Processing Record 6 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 15 | kasra
# City not found. Skipping...
# Processing Record 8 of Set 15 | carahue
# Processing Record 9 of Set 15 | mandera
# Processing Record 10 of Set 15 | selikhino
# Processing Record 11 of Set 15 | springbok
# Processing Record 12 of Set 15 | bridgetown
# Processing Record 13 of Set 15 | kazbegi
# City not found. Skipping...
# Processing Record 14 of Set 15 | gambela
# Processing Record 15 of Set 15 | tazmalt
# Processing Record 16 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 15 | mayumba
# Processing Record 18 of Set 15 | tirumullaivasal
# Processing Record 19 of Set 15 | mongar
# Processing Record 20 of Set 15 | west plains
# Processing Record 21 of Set 15 | russell
# Processing Record 22 of Set 15 | inhambane
# Processing Record 23 of Set 15 | aykhal
# Processing Record 24 of Set 15 | manitouwadge
# Processing Record 25 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 15 | surt
# Processing Record 27 of Set 15 | lemon grove
# Processing Record 28 of Set 15 | santa fe do sul
# Processing Record 29 of Set 15 | iberia
# Processing Record 30 of Set 15 | itacoatiara
# Processing Record 31 of Set 15 | tigil
# Processing Record 32 of Set 15 | kushmurun
# Processing Record 33 of Set 15 | ejido
# Processing Record 34 of Set 15 | sovetskiy
# Processing Record 35 of Set 15 | muros
# Processing Record 36 of Set 15 | mayo
# Processing Record 37 of Set 15 | palanga
# Processing Record 38 of Set 15 | tungor
# Processing Record 39 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 15 | luang prabang
# Processing Record 41 of Set 15 | khandyga
# Processing Record 42 of Set 15 | rio gallegos
# Processing Record 43 of Set 15 | sao paulo de olivenca
# Processing Record 44 of Set 15 | syracuse
# Processing Record 45 of Set 15 | toamasina
# Processing Record 46 of Set 15 | jining
# Processing Record 47 of Set 15 | pimentel
# Processing Record 48 of Set 15 | ucluelet
# Processing Record 49 of Set 15 | kautokeino
# Processing Record 50 of Set 15 | tiarei
# Processing Record 1 of Set 16 | manicore
# Processing Record 2 of Set 16 | kharela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_wind
# Out:
# 5.55

# %%
city_descr
# Out:
# 'clear sky'

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Dakar  14.6937  -17.4441     88.68        79           0        6.91
# 1     Husavik  66.0449  -17.3389     40.91        99          66        8.43
# 2     Rikitea -23.1203 -134.9692     73.58        78         100       12.59
# 3  Lavrentiya  65.5833 -171.0000     14.27        82         100       12.03
# 4   Thinadhoo   0.5333   72.9333     83.50        67         100       13.15
# 5  Bredasdorp -34.5322   20.0403     65.52        63         100       25.32
# 6   Geraldton -28.7667  114.6000     63.01        77          90       12.66
# 7     Kuntaur  13.6667  -14.8833     88.27        50          48        8.79
# 8   Hithadhoo  -0.6000   73.0833     82.31        74          83        9.69
# 9        Faya  18.3851   42.4509     64.51        35           0        3.24
#
#   Country       Description        Date
# 0      SN         clear sky  2021-11-04
# 1      IS     broken clouds  2021-11-04
# 2      PF        light rain  2021-11-04
# 3      RU   overcast clouds  2021-11-04
# 4      MV   overcast clouds  2021-11-04
# 5      ZA   overcast clouds  2021-11-04
# 6      AU   overcast clouds  2021-11-04
# 7      GM  scattered clouds  2021-11-04
# 8      MV     broken clouds  2021-11-04
# 9      SA         clear sky  2021-11-04

# %%
new_column_order = ['City', 'Country',  'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0       Dakar      SN  2021-11-04  14.6937  -17.4441     88.68        79
# 1     Husavik      IS  2021-11-04  66.0449  -17.3389     40.91        99
# 2     Rikitea      PF  2021-11-04 -23.1203 -134.9692     73.58        78
# 3  Lavrentiya      RU  2021-11-04  65.5833 -171.0000     14.27        82
# 4   Thinadhoo      MV  2021-11-04   0.5333   72.9333     83.50        67
# 5  Bredasdorp      ZA  2021-11-04 -34.5322   20.0403     65.52        63
# 6   Geraldton      AU  2021-11-04 -28.7667  114.6000     63.01        77
# 7     Kuntaur      GM  2021-11-04  13.6667  -14.8833     88.27        50
# 8   Hithadhoo      MV  2021-11-04  -0.6000   73.0833     82.31        74
# 9        Faya      SA  2021-11-04  18.3851   42.4509     64.51        35
#
#    Cloudiness  Wind Speed       Description
# 0           0        6.91         clear sky
# 1          66        8.43     broken clouds
# 2         100       12.59        light rain
# 3         100       12.03   overcast clouds
# 4         100       13.15   overcast clouds
# 5         100       25.32   overcast clouds
# 6          90       12.66   overcast clouds
# 7          48        8.79  scattered clouds
# 8          83        9.69     broken clouds
# 9           0        3.24         clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
