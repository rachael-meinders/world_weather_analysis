# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
city_data = []

# %%
len(city_data)
# Out:
# 0

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | touros
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | haines junction
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | develi
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 1 | pontianak
# Processing Record 22 of Set 1 | khasan
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | krasnoselkup
# Processing Record 30 of Set 1 | kirkwall
# Processing Record 31 of Set 1 | broken hill
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | ahipara
# Processing Record 34 of Set 1 | vysokogornyy
# Processing Record 35 of Set 1 | oksfjord
# Processing Record 36 of Set 1 | maloshuyka
# City not found. Skipping...
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | anadyr
# Processing Record 39 of Set 1 | fethiye
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | porto santo
# Processing Record 42 of Set 1 | chernyshevskiy
# Processing Record 43 of Set 1 | raga
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | port hedland
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 1 | nuuk
# Processing Record 49 of Set 1 | rawson
# Processing Record 50 of Set 1 | hamilton
# Processing Record 1 of Set 2 | kruisfontein
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | obihiro
# Processing Record 7 of Set 2 | wamba
# Processing Record 8 of Set 2 | paamiut
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | hurghada
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | tuatapere
# Processing Record 14 of Set 2 | klaksvik
# Processing Record 15 of Set 2 | coihaique
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | smithers
# Processing Record 23 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 2 | eureka
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | namatanai
# Processing Record 27 of Set 2 | nanortalik
# Processing Record 28 of Set 2 | baturinskaya
# Processing Record 29 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 2 | panji
# Processing Record 31 of Set 2 | beaverlodge
# Processing Record 32 of Set 2 | baoning
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | villa carlos paz
# Processing Record 36 of Set 2 | tsabong
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | natal
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | koslan
# Processing Record 42 of Set 2 | kashan
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | rio branco
# Processing Record 46 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | strezhevoy
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | kununurra
# Processing Record 1 of Set 3 | yulara
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | khingansk
# Processing Record 4 of Set 3 | bom jesus
# Processing Record 5 of Set 3 | funadhoo
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | berlevag
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | cayenne
# Processing Record 10 of Set 3 | bonavista
# Processing Record 11 of Set 3 | borama
# City not found. Skipping...
# Processing Record 12 of Set 3 | cervo
# Processing Record 13 of Set 3 | ileza
# Processing Record 14 of Set 3 | shimoda
# Processing Record 15 of Set 3 | turukhansk
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | tessalit
# Processing Record 18 of Set 3 | jardim
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | acapulco
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | george
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | saint george
# Processing Record 25 of Set 3 | sycow
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | masingbi
# Processing Record 28 of Set 3 | fuerte olimpo
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | santa maria
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | axim
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | porto novo
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | katobu
# Processing Record 38 of Set 3 | sarab
# Processing Record 39 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | yar-sale
# Processing Record 42 of Set 3 | port blair
# Processing Record 43 of Set 3 | yumen
# Processing Record 44 of Set 3 | naron
# Processing Record 45 of Set 3 | cavalcante
# Processing Record 46 of Set 3 | the hague
# Processing Record 47 of Set 3 | albion
# Processing Record 48 of Set 3 | palmer
# Processing Record 49 of Set 3 | krasnokamensk
# Processing Record 50 of Set 3 | wanning
# Processing Record 1 of Set 4 | talnakh
# Processing Record 2 of Set 4 | marovoay
# Processing Record 3 of Set 4 | shimorskoye
# Processing Record 4 of Set 4 | saskylakh
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | rosa zarate
# Processing Record 10 of Set 4 | kishtwar
# Processing Record 11 of Set 4 | newberry
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | saint-augustin
# Processing Record 14 of Set 4 | saint-pierre
# Processing Record 15 of Set 4 | guerrero negro
# Processing Record 16 of Set 4 | salalah
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | a
# City not found. Skipping...
# Processing Record 20 of Set 4 | inuvik
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | sorland
# Processing Record 23 of Set 4 | manggar
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | gigmoto
# Processing Record 27 of Set 4 | port hardy
# Processing Record 28 of Set 4 | bathsheba
# Processing Record 29 of Set 4 | tahta
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | olafsvik
# Processing Record 34 of Set 4 | nizhniy tsasuchey
# Processing Record 35 of Set 4 | belaya gora
# Processing Record 36 of Set 4 | ambilobe
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | veraval
# Processing Record 39 of Set 4 | trairi
# Processing Record 40 of Set 4 | nkhata bay
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | thompson
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | yatou
# Processing Record 46 of Set 4 | udachnyy
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | hasaki
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | yerbogachen
# Processing Record 1 of Set 5 | saldanha
# Processing Record 2 of Set 5 | vanimo
# Processing Record 3 of Set 5 | avera
# Processing Record 4 of Set 5 | petropavlovka
# Processing Record 5 of Set 5 | los llanos de aridane
# Processing Record 6 of Set 5 | naze
# Processing Record 7 of Set 5 | piacabucu
# Processing Record 8 of Set 5 | yefimovskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | manokwari
# Processing Record 10 of Set 5 | taksimo
# Processing Record 11 of Set 5 | dingle
# Processing Record 12 of Set 5 | hilo
# Processing Record 13 of Set 5 | kot putli
# City not found. Skipping...
# Processing Record 14 of Set 5 | cairns
# Processing Record 15 of Set 5 | teyateyaneng
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | jaisinghnagar
# Processing Record 18 of Set 5 | yazd
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | manzhouli
# Processing Record 21 of Set 5 | itacarambi
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | okato
# Processing Record 24 of Set 5 | iquique
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | puerto ayora
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | kirakira
# Processing Record 29 of Set 5 | lebedinyy
# Processing Record 30 of Set 5 | aksha
# Processing Record 31 of Set 5 | honiara
# Processing Record 32 of Set 5 | aleksandrovka
# Processing Record 33 of Set 5 | shu
# Processing Record 34 of Set 5 | kangaatsiaq
# Processing Record 35 of Set 5 | mildura
# Processing Record 36 of Set 5 | beitbridge
# Processing Record 37 of Set 5 | anahuac
# Processing Record 38 of Set 5 | mayo
# Processing Record 39 of Set 5 | katangli
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | khorinsk
# Processing Record 42 of Set 5 | tak
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | egvekinot
# Processing Record 47 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 5 | ternate
# Processing Record 49 of Set 5 | antofagasta
# Processing Record 50 of Set 5 | rongcheng
# Processing Record 1 of Set 6 | posse
# Processing Record 2 of Set 6 | quatre cocos
# Processing Record 3 of Set 6 | asfi
# Processing Record 4 of Set 6 | severo-kurilsk
# Processing Record 5 of Set 6 | stromness
# Processing Record 6 of Set 6 | suntar
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | gravdal
# Processing Record 9 of Set 6 | moron
# Processing Record 10 of Set 6 | flinders
# Processing Record 11 of Set 6 | burnie
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | maroua
# Processing Record 14 of Set 6 | bahia blanca
# Processing Record 15 of Set 6 | valleyview
# Processing Record 16 of Set 6 | agadez
# Processing Record 17 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 6 | yarada
# Processing Record 19 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | pisco
# Processing Record 22 of Set 6 | beringovskiy
# Processing Record 23 of Set 6 | sungaipenuh
# Processing Record 24 of Set 6 | chimbote
# Processing Record 25 of Set 6 | benton harbor
# Processing Record 26 of Set 6 | mae hong son
# Processing Record 27 of Set 6 | westport
# Processing Record 28 of Set 6 | birin
# Processing Record 29 of Set 6 | mitu
# Processing Record 30 of Set 6 | kuah
# Processing Record 31 of Set 6 | coquimbo
# Processing Record 32 of Set 6 | aberdeen
# Processing Record 33 of Set 6 | pandan
# Processing Record 34 of Set 6 | camargo
# Processing Record 35 of Set 6 | kovdor
# Processing Record 36 of Set 6 | lubumbashi
# Processing Record 37 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 6 | borogontsy
# Processing Record 39 of Set 6 | moche
# Processing Record 40 of Set 6 | uyovu
# Processing Record 41 of Set 6 | amahai
# Processing Record 42 of Set 6 | champerico
# Processing Record 43 of Set 6 | shobara
# Processing Record 44 of Set 6 | wajir
# Processing Record 45 of Set 6 | lebyazhye
# Processing Record 46 of Set 6 | alofi
# Processing Record 47 of Set 6 | tiznit
# Processing Record 48 of Set 6 | buala
# Processing Record 49 of Set 6 | ugoofaaru
# Processing Record 50 of Set 6 | tasiilaq
# Processing Record 1 of Set 7 | deming
# Processing Record 2 of Set 7 | okhotsk
# Processing Record 3 of Set 7 | dillon
# Processing Record 4 of Set 7 | nelson bay
# Processing Record 5 of Set 7 | linguere
# Processing Record 6 of Set 7 | kalaleh
# Processing Record 7 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 7 | caravelas
# Processing Record 9 of Set 7 | bentiu
# Processing Record 10 of Set 7 | karasjok
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | broome
# Processing Record 13 of Set 7 | pedernales
# Processing Record 14 of Set 7 | imeni babushkina
# Processing Record 15 of Set 7 | lorengau
# Processing Record 16 of Set 7 | sokoni
# Processing Record 17 of Set 7 | contamana
# Processing Record 18 of Set 7 | hebi
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | monrovia
# Processing Record 21 of Set 7 | rorvik
# Processing Record 22 of Set 7 | betanzos
# Processing Record 23 of Set 7 | hualmay
# Processing Record 24 of Set 7 | killarney
# Processing Record 25 of Set 7 | khani
# Processing Record 26 of Set 7 | tutoia
# Processing Record 27 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 7 | matara
# Processing Record 29 of Set 7 | puerto escondido
# Processing Record 30 of Set 7 | pingliang
# Processing Record 31 of Set 7 | vangaindrano
# Processing Record 32 of Set 7 | hervey bay
# Processing Record 33 of Set 7 | semey
# Processing Record 34 of Set 7 | templemore
# Processing Record 35 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 7 | baykit
# Processing Record 38 of Set 7 | tautira
# Processing Record 39 of Set 7 | werda
# Processing Record 40 of Set 7 | ouricuri
# Processing Record 41 of Set 7 | groningen
# Processing Record 42 of Set 7 | bolgatanga
# Processing Record 43 of Set 7 | nemuro
# Processing Record 44 of Set 7 | busteni
# Processing Record 45 of Set 7 | pakaur
# Processing Record 46 of Set 7 | nome
# Processing Record 47 of Set 7 | conceicao do araguaia
# Processing Record 48 of Set 7 | langsa
# Processing Record 49 of Set 7 | mato verde
# Processing Record 50 of Set 7 | aswan
# Processing Record 1 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 8 | faridkot
# Processing Record 4 of Set 8 | aloleng
# Processing Record 5 of Set 8 | melito di porto salvo
# Processing Record 6 of Set 8 | san jose
# Processing Record 7 of Set 8 | paraiso
# Processing Record 8 of Set 8 | hobyo
# Processing Record 9 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | poum
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 8 | cidreira
# Processing Record 14 of Set 8 | voi
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 8 | hovd
# Processing Record 17 of Set 8 | nanyang
# Processing Record 18 of Set 8 | sao joao da barra
# Processing Record 19 of Set 8 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 20 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 21 of Set 8 | amapa
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | martil
# Processing Record 24 of Set 8 | bambous virieux
# Processing Record 25 of Set 8 | gorom-gorom
# Processing Record 26 of Set 8 | makat
# Processing Record 27 of Set 8 | santa cruz
# Processing Record 28 of Set 8 | fairbanks
# Processing Record 29 of Set 8 | nouadhibou
# Processing Record 30 of Set 8 | chute-aux-outardes
# Processing Record 31 of Set 8 | sambava
# Processing Record 32 of Set 8 | roma
# Processing Record 33 of Set 8 | buchanan
# Processing Record 34 of Set 8 | lewisporte
# Processing Record 35 of Set 8 | longyearbyen
# Processing Record 36 of Set 8 | kinablangan
# Processing Record 37 of Set 8 | shubarkuduk
# Processing Record 38 of Set 8 | roald
# Processing Record 39 of Set 8 | kandrian
# Processing Record 40 of Set 8 | virovitica
# Processing Record 41 of Set 8 | airai
# Processing Record 42 of Set 8 | mapimi
# Processing Record 43 of Set 8 | macusani
# Processing Record 44 of Set 8 | ler
# Processing Record 45 of Set 8 | abu samrah
# Processing Record 46 of Set 8 | alpena
# Processing Record 47 of Set 8 | novomyrhorod
# Processing Record 48 of Set 8 | neiafu
# Processing Record 49 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 8 | korla
# Processing Record 1 of Set 9 | pakhtakoron
# Processing Record 2 of Set 9 | teontepec
# Processing Record 3 of Set 9 | kuytun
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | svetlogorsk
# Processing Record 6 of Set 9 | sonoita
# Processing Record 7 of Set 9 | wewak
# Processing Record 8 of Set 9 | sovetskaya gavan
# Processing Record 9 of Set 9 | bambanglipuro
# Processing Record 10 of Set 9 | morgan city
# Processing Record 11 of Set 9 | santa lucia
# Processing Record 12 of Set 9 | shache
# Processing Record 13 of Set 9 | sitka
# Processing Record 14 of Set 9 | lindi
# Processing Record 15 of Set 9 | bonfim
# Processing Record 16 of Set 9 | beidao
# Processing Record 17 of Set 9 | takob
# City not found. Skipping...
# Processing Record 18 of Set 9 | seddon
# Processing Record 19 of Set 9 | burica
# City not found. Skipping...
# Processing Record 20 of Set 9 | shirokiy
# Processing Record 21 of Set 9 | praia da vitoria
# Processing Record 22 of Set 9 | flin flon
# Processing Record 23 of Set 9 | songadh
# Processing Record 24 of Set 9 | calbuco
# Processing Record 25 of Set 9 | the valley
# Processing Record 26 of Set 9 | deputatskiy
# Processing Record 27 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 9 | namalenga
# Processing Record 29 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 30 of Set 9 | sao filipe
# Processing Record 31 of Set 9 | jaru
# Processing Record 32 of Set 9 | segezha
# Processing Record 33 of Set 9 | bela
# Processing Record 34 of Set 9 | beaune
# Processing Record 35 of Set 9 | ostrovnoy
# Processing Record 36 of Set 9 | agirish
# Processing Record 37 of Set 9 | rye
# Processing Record 38 of Set 9 | pinawa
# Processing Record 39 of Set 9 | tadine
# Processing Record 40 of Set 9 | guarapari
# Processing Record 41 of Set 9 | santa vitoria do palmar
# Processing Record 42 of Set 9 | oistins
# Processing Record 43 of Set 9 | bharatpur
# Processing Record 44 of Set 9 | bojnurd
# Processing Record 45 of Set 9 | yongan
# Processing Record 46 of Set 9 | sovetskiy
# Processing Record 47 of Set 9 | catamarca
# Processing Record 48 of Set 9 | phan thiet
# Processing Record 49 of Set 9 | fortuna
# Processing Record 50 of Set 9 | ippy
# Processing Record 1 of Set 10 | tambun
# Processing Record 2 of Set 10 | marfino
# Processing Record 3 of Set 10 | anloga
# Processing Record 4 of Set 10 | leshukonskoye
# Processing Record 5 of Set 10 | ginir
# Processing Record 6 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 7 of Set 10 | abu kamal
# Processing Record 8 of Set 10 | muros
# Processing Record 9 of Set 10 | bikaner
# Processing Record 10 of Set 10 | benguela
# Processing Record 11 of Set 10 | marilia
# Processing Record 12 of Set 10 | envira
# Processing Record 13 of Set 10 | necochea
# Processing Record 14 of Set 10 | elizabeth city
# Processing Record 15 of Set 10 | mount gambier
# Processing Record 16 of Set 10 | amazar
# Processing Record 17 of Set 10 | aalten
# Processing Record 18 of Set 10 | marsa matruh
# Processing Record 19 of Set 10 | comines
# Processing Record 20 of Set 10 | maracas
# Processing Record 21 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 10 | tabuk
# Processing Record 23 of Set 10 | komsomolskiy
# Processing Record 24 of Set 10 | tateyama
# Processing Record 25 of Set 10 | santa isabel do rio negro
# Processing Record 26 of Set 10 | bonthe
# Processing Record 27 of Set 10 | yenangyaung
# Processing Record 28 of Set 10 | dubai
# Processing Record 29 of Set 10 | olinda
# Processing Record 30 of Set 10 | yarmouth
# Processing Record 31 of Set 10 | russkaya polyana
# Processing Record 32 of Set 10 | sanandaj
# Processing Record 33 of Set 10 | searcy
# Processing Record 34 of Set 10 | calabar
# Processing Record 35 of Set 10 | ust-maya
# Processing Record 36 of Set 10 | challapata
# Processing Record 37 of Set 10 | hami
# Processing Record 38 of Set 10 | raudeberg
# Processing Record 39 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 10 | honningsvag
# Processing Record 42 of Set 10 | hayden
# Processing Record 43 of Set 10 | grand-santi
# Processing Record 44 of Set 10 | borovskoy
# Processing Record 45 of Set 10 | muzhi
# Processing Record 46 of Set 10 | kashi
# Processing Record 47 of Set 10 | makakilo city
# Processing Record 48 of Set 10 | solnechnyy
# Processing Record 49 of Set 10 | richards bay
# Processing Record 50 of Set 10 | pemba
# Processing Record 1 of Set 11 | zamora
# Processing Record 2 of Set 11 | tigil
# Processing Record 3 of Set 11 | starodub
# Processing Record 4 of Set 11 | manyana
# Processing Record 5 of Set 11 | dauriya
# Processing Record 6 of Set 11 | kalmunai
# Processing Record 7 of Set 11 | timmins
# Processing Record 8 of Set 11 | haverfordwest
# Processing Record 9 of Set 11 | panama city
# Processing Record 10 of Set 11 | riyadh
# Processing Record 11 of Set 11 | bubaque
# Processing Record 12 of Set 11 | mangan
# Processing Record 13 of Set 11 | aiantion
# City not found. Skipping...
# Processing Record 14 of Set 11 | hinatuan
# Processing Record 15 of Set 11 | vaitape
# Processing Record 16 of Set 11 | celestun
# Processing Record 17 of Set 11 | high level
# Processing Record 18 of Set 11 | cascavel
# Processing Record 19 of Set 11 | xichang
# Processing Record 20 of Set 11 | oudtshoorn
# Processing Record 21 of Set 11 | san jeronimo
# Processing Record 22 of Set 11 | san cristobal
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | sechura
# Processing Record 25 of Set 11 | krasnaya poyma
# Processing Record 26 of Set 11 | camacha
# Processing Record 27 of Set 11 | alyangula
# Processing Record 28 of Set 11 | caceres
# Processing Record 29 of Set 11 | chumikan
# Processing Record 30 of Set 11 | karatau
# Processing Record 31 of Set 11 | gravelbourg
# Processing Record 32 of Set 11 | mitsamiouli
# Processing Record 33 of Set 11 | qurayyat
# Processing Record 34 of Set 11 | nouakchott
# Processing Record 35 of Set 11 | ust-kuyga
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | mogok
# Processing Record 38 of Set 11 | chifeng
# Processing Record 39 of Set 11 | jalu
# Processing Record 40 of Set 11 | shushtar
# Processing Record 41 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 11 | oravita
# Processing Record 43 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 11 | loralai
# Processing Record 45 of Set 11 | botevgrad
# Processing Record 46 of Set 11 | karmana
# City not found. Skipping...
# Processing Record 47 of Set 11 | tashtyp
# Processing Record 48 of Set 11 | praya
# Processing Record 49 of Set 11 | idrinskoye
# Processing Record 50 of Set 11 | opuwo
# Processing Record 1 of Set 12 | moorhead
# Processing Record 2 of Set 12 | pundaguitan
# Processing Record 3 of Set 12 | sao felix do xingu
# Processing Record 4 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 12 | alfafar
# Processing Record 6 of Set 12 | teneguiban
# City not found. Skipping...
# Processing Record 7 of Set 12 | ekibastuz
# Processing Record 8 of Set 12 | hailey
# Processing Record 9 of Set 12 | isangel
# Processing Record 10 of Set 12 | dum duma
# Processing Record 11 of Set 12 | kansay
# City not found. Skipping...
# Processing Record 12 of Set 12 | guadalupe y calvo
# Processing Record 13 of Set 12 | ballina
# Processing Record 14 of Set 12 | imeni poliny osipenko
# Processing Record 15 of Set 12 | fare
# Processing Record 16 of Set 12 | sendhwa
# Processing Record 17 of Set 12 | vao
# Processing Record 18 of Set 12 | seymchan
# Processing Record 19 of Set 12 | vilhena
# Processing Record 20 of Set 12 | zhicheng
# Processing Record 21 of Set 12 | bengbu
# Processing Record 22 of Set 12 | marawi
# Processing Record 23 of Set 12 | tornio
# Processing Record 24 of Set 12 | pangnirtung
# Processing Record 25 of Set 12 | verkhnetulomskiy
# Processing Record 26 of Set 12 | zhanaozen
# Processing Record 27 of Set 12 | caraballeda
# Processing Record 28 of Set 12 | saryg-sep
# Processing Record 29 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 12 | healesville
# Processing Record 31 of Set 12 | saint-joseph
# Processing Record 32 of Set 12 | wajima
# Processing Record 33 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 12 | quchan
# Processing Record 35 of Set 12 | vila velha
# Processing Record 36 of Set 12 | luau
# Processing Record 37 of Set 12 | ushibuka
# Processing Record 38 of Set 12 | lakes entrance
# Processing Record 39 of Set 12 | mecca
# Processing Record 40 of Set 12 | port moresby
# Processing Record 41 of Set 12 | vavoua
# Processing Record 42 of Set 12 | zavetnoye
# Processing Record 43 of Set 12 | atchison
# Processing Record 44 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 12 | tezu
# Processing Record 46 of Set 12 | beroroha
# Processing Record 47 of Set 12 | strakonice
# Processing Record 48 of Set 12 | college
# Processing Record 49 of Set 12 | kocevje
# Processing Record 50 of Set 12 | la asuncion
# Processing Record 1 of Set 13 | iralaya
# Processing Record 2 of Set 13 | morondava
# Processing Record 3 of Set 13 | alta floresta
# Processing Record 4 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 13 | carnaiba
# Processing Record 6 of Set 13 | toucheng
# Processing Record 7 of Set 13 | lazaro cardenas
# Processing Record 8 of Set 13 | christchurch
# Processing Record 9 of Set 13 | pizarro
# Processing Record 10 of Set 13 | puerto baquerizo moreno
# Processing Record 11 of Set 13 | lethem
# Processing Record 12 of Set 13 | bonnyville
# Processing Record 13 of Set 13 | magadan
# Processing Record 14 of Set 13 | ankang
# Processing Record 15 of Set 13 | rio grande
# Processing Record 16 of Set 13 | datong
# Processing Record 17 of Set 13 | brae
# Processing Record 18 of Set 13 | medicine hat
# Processing Record 19 of Set 13 | san vicente
# Processing Record 20 of Set 13 | port augusta
# Processing Record 21 of Set 13 | freeport
# Processing Record 22 of Set 13 | gramsh
# Processing Record 23 of Set 13 | kalikino
# Processing Record 24 of Set 13 | gat
# Processing Record 25 of Set 13 | jacareacanga
# Processing Record 26 of Set 13 | ha tinh
# Processing Record 27 of Set 13 | tabor
# Processing Record 28 of Set 13 | bartica
# Processing Record 29 of Set 13 | saurimo
# Processing Record 30 of Set 13 | rio gallegos
# Processing Record 31 of Set 13 | noormarkku
# Processing Record 32 of Set 13 | fenoarivo
# Processing Record 33 of Set 13 | mairana
# Processing Record 34 of Set 13 | oriximina
# Processing Record 35 of Set 13 | oktyabrskiy
# Processing Record 36 of Set 13 | whitehorse
# Processing Record 37 of Set 13 | hohhot
# Processing Record 38 of Set 13 | langxiang
# Processing Record 39 of Set 13 | evensk
# Processing Record 40 of Set 13 | palu
# Processing Record 41 of Set 13 | la baneza
# Processing Record 42 of Set 13 | wilmington
# Processing Record 43 of Set 13 | coari
# Processing Record 44 of Set 13 | nanakuli
# Processing Record 45 of Set 13 | san patricio
# Processing Record 46 of Set 13 | kudahuvadhoo
# Processing Record 47 of Set 13 | knysna
# Processing Record 48 of Set 13 | chicama
# Processing Record 49 of Set 13 | cordele
# Processing Record 50 of Set 13 | nogliki
# Processing Record 1 of Set 14 | novikovo
# Processing Record 2 of Set 14 | amuntai
# Processing Record 3 of Set 14 | tadpatri
# Processing Record 4 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 14 | san quintin
# Processing Record 6 of Set 14 | altamont
# Processing Record 7 of Set 14 | iskateley
# Processing Record 8 of Set 14 | zatoka
# Processing Record 9 of Set 14 | cabinda
# Processing Record 10 of Set 14 | shar
# Processing Record 11 of Set 14 | miraflores
# Processing Record 12 of Set 14 | nhulunbuy
# Processing Record 13 of Set 14 | itarema
# Processing Record 14 of Set 14 | ust-barguzin
# Processing Record 15 of Set 14 | milkovo
# Processing Record 16 of Set 14 | road town
# Processing Record 17 of Set 14 | maningrida
# Processing Record 18 of Set 14 | walvis bay
# Processing Record 19 of Set 14 | fort-shevchenko
# Processing Record 20 of Set 14 | arlit
# Processing Record 21 of Set 14 | half moon bay
# Processing Record 22 of Set 14 | luza
# Processing Record 23 of Set 14 | istanbul
# Processing Record 24 of Set 14 | nioki
# Processing Record 25 of Set 14 | kisangani
# Processing Record 26 of Set 14 | nalut
# Processing Record 27 of Set 14 | colares
# Processing Record 28 of Set 14 | taoudenni
# Processing Record 29 of Set 14 | hun
# Processing Record 30 of Set 14 | poya
# Processing Record 31 of Set 14 | narsaq
# Processing Record 32 of Set 14 | ararangua
# Processing Record 33 of Set 14 | mao
# Processing Record 34 of Set 14 | ouro preto do oeste
# Processing Record 35 of Set 14 | lesnoy
# Processing Record 36 of Set 14 | charters towers
# Processing Record 37 of Set 14 | mairang
# Processing Record 38 of Set 14 | sydney
# Processing Record 39 of Set 14 | port-cartier
# Processing Record 40 of Set 14 | aktas
# Processing Record 41 of Set 14 | karratha
# Processing Record 42 of Set 14 | puerto rico
# Processing Record 43 of Set 14 | podgorica
# Processing Record 44 of Set 14 | rock sound
# Processing Record 45 of Set 14 | panorama
# Processing Record 46 of Set 14 | grong
# Processing Record 47 of Set 14 | killybegs
# Processing Record 48 of Set 14 | petatlan
# Processing Record 49 of Set 14 | dondo
# Processing Record 50 of Set 14 | aykhal
# Processing Record 1 of Set 15 | porbandar
# Processing Record 2 of Set 15 | tabas
# Processing Record 3 of Set 15 | dzilam gonzalez
# Processing Record 4 of Set 15 | nova granada
# Processing Record 5 of Set 15 | saint-leu
# Processing Record 6 of Set 15 | chadan
# Processing Record 7 of Set 15 | victor harbor
# Processing Record 8 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 15 | idukki
# Processing Record 10 of Set 15 | srednekolymsk
# Processing Record 11 of Set 15 | vratnica
# Processing Record 12 of Set 15 | lufilufi
# Processing Record 13 of Set 15 | swinoujscie
# Processing Record 14 of Set 15 | doha
# Processing Record 15 of Set 15 | marsaxlokk
# Processing Record 16 of Set 15 | normandin
# Processing Record 17 of Set 15 | xai-xai
# Processing Record 18 of Set 15 | khandyga
# Processing Record 19 of Set 15 | sarh
# Processing Record 20 of Set 15 | tarauaca
# Processing Record 21 of Set 15 | peniche
# Processing Record 22 of Set 15 | kachug
# Processing Record 23 of Set 15 | labrea
# Processing Record 24 of Set 15 | kita
# Processing Record 25 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 15 | san rafael
# Processing Record 27 of Set 15 | oxford
# Processing Record 28 of Set 15 | saint-georges
# Processing Record 29 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 15 | altay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ponta Do Sol  32.6667  -17.1000     71.71        80         100
# 1        Carnarvon -24.8667  113.6333     69.87        68           0
# 2      New Norfolk -42.7826  147.0587     66.65        52           5
# 3         Khatanga  71.9667  102.5000     12.63        94         100
# 4      Provideniya  64.3833 -173.3000     14.67        83          99
# 5           Touros  -5.1989  -35.4608     81.50        82          39
# 6  Arraial Do Cabo -22.9661  -42.0278     71.40        91         100
# 7           Avarua -21.2078 -159.7750     78.85        69          20
# 8       Nikolskoye  59.7035   30.7861     46.87        91         100
# 9  Haines Junction  60.7522 -137.5108     39.15        60          28
#
#    Wind Speed Country                 Date
# 0        7.29      PT  2021-11-04 01:22:15
# 1       19.57      AU  2021-11-04 01:20:27
# 2        1.99      AU  2021-11-04 01:13:56
# 3       20.09      RU  2021-11-04 01:20:43
# 4       11.12      RU  2021-11-04 01:19:12
# 5       12.37      BR  2021-11-04 01:22:18
# 6        6.82      BR  2021-11-04 01:17:51
# 7       13.80      CK  2021-11-04 01:10:47
# 8        7.83      RU  2021-11-04 01:16:07
# 9        3.44      CA  2021-11-04 01:22:21
